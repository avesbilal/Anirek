# %% [markdown]
# # **DATA COLLECTION**
# ---
#
# **Data Source:** https://www.kaggle.com/datasets/dbdmobile/myanimelist-dataset

# %% [markdown]
# # **DATA CLEANING**

# %%
import pandas as pd
df = pd.read_csv('dataset.csv')
df
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %%
df.isna().sum()
# Out:
# anime_id        0
# Name            0
# English name    0
# Other name      0
# Score           0
# Genres          0
# Synopsis        0
# Type            0
# Episodes        0
# Aired           0
# Premiered       0
# Status          0
# Producers       0
# Licensors       0
# Studios         0
# Source          0
# Duration        0
# Rating          0
# Rank            0
# Popularity      0
# Favorites       0
# Scored By       0
# Members         0
# Image URL       0
# dtype: int64

# %%
# Display all unique anime type
unique_types = df['Type'].unique()
print("Unique Types:", unique_types, "\n")

# Count of each unique value in the 'Type' column
type_counts = df['Type'].value_counts()
print(type_counts)
# Out:
# Unique Types: ['TV' 'Movie' 'OVA' 'Special' 'ONA' 'Music' 'UNKNOWN']
#
# TV         7597
# Movie      4381
# OVA        4076
# ONA        3533
# Music      2686
# Special    2558
# UNKNOWN      74
# Name: Type, dtype: int64

# %%
df = df[df['Type'].isin(['TV', 'Movie'])]
df
# Out:
#        anime_id                                               Name  \
# 0             1                                       Cowboy Bebop
# 1             5                    Cowboy Bebop: Tengoku no Tobira
# 2             6                                             Trigun
# 3             7                                 Witch Hunter Robin
# 4             8                                     Bouken Ou Beet
# ...         ...                                                ...
# 24875     55701                Kimetsu no Yaiba: Hashira Geiko-hen
# 24876     55702             Kimetsu no Yaiba: Purātorēninguāku-hen
# 24882     55709                               Boku to Roboko Movie
# 24884     55714                                       Retro Future
# 24886     55717  Dekisokonai to Yobareta Motoeiyuu wa Jikka kar...
#
#                                             English name  \
# 0                                           Cowboy Bebop
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#        anime_id                                               Name  \
# 0             1                                       Cowboy Bebop
# 1             5                    Cowboy Bebop: Tengoku no Tobira
# 2             6                                             Trigun
# 3             7                                 Witch Hunter Robin
# 4             8                                     Bouken Ou Beet
# ...         ...                                                ...
# 11973     55701                Kimetsu no Yaiba: Hashira Geiko-hen
# 11974     55702             Kimetsu no Yaiba: Purātorēninguāku-hen
# 11975     55709                               Boku to Roboko Movie
# 11976     55714                                       Retro Future
# 11977     55717  Dekisokonai to Yobareta Motoeiyuu wa Jikka kar...
#
#                                             English name  \
# 0                                           Cowboy Bebop
# ...

# %%
unknown_values = df['English name'].value_counts()
print(unknown_values)
# Out:
# UNKNOWN                                               5969
# Cyborg 009                                               4
# Meow Meow Japanese History                               4
# Digimon Fusion                                           3
# Bernard                                                  3
#                                                       ...
# Astarotte's Toy                                          1
# Broken Blade 5                                           1
# Maria†Holic Alive                                        1
# Kimi ni Todoke: From Me to You Season 2                  1
# Demon slayer: Kimetsu no yaiba pillar training arc       1
# Name: English name, Length: 5950, dtype: int64

# %%
unknown_values = df['Name'].value_counts()
print(unknown_values)
# Out:
# Cowboy Bebop                                                                                            1
# Taiyang de Xiao Keren                                                                                   1
# Pa Xiu De Huang Ying                                                                                    1
# Da Luo Bo                                                                                               1
# Yuan Xing Bi Lu                                                                                         1
#                                                                                                        ..
# Kankara Sanshin                                                                                         1
# Sore Ike! Anpanman: Roll to Laura Ukigumojou no Himitsu                                                 1
# Jib                                                                                                     1
# ...

# %% [markdown]
# **Converting Anime titles from Japanese to English**

# %%
df.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %% [markdown]
# # **Required Features for Our Model**
#
# To  build anime recommendation system, the following features are required:
#
# - **ID**
# - **Name**
# - **Overview**
# - **Genre**
# - **Image URL**

# %%
df.rename(columns={
    'anime_id': 'id',
    'Name': 'name',
    'Genres': 'genre',
    'Synopsis': 'overview',
    'Image URL': 'img_url'
    }, inplace=True)
# Out:
# /var/folders/4l/vhl9mh4n00x7t930gk0lrc_m0000gn/T/ipykernel_9879/4061753928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
selected_features = ['id','name','genre', 'overview', 'img_url']
anime = df[selected_features]
anime
# Out:
#           id                                               name  \
# 0          1                                       Cowboy Bebop
# 1          5                    Cowboy Bebop: Tengoku no Tobira
# 2          6                                             Trigun
# 3          7                                 Witch Hunter Robin
# 4          8                                     Bouken Ou Beet
# ...      ...                                                ...
# 11973  55701                Kimetsu no Yaiba: Hashira Geiko-hen
# 11974  55702             Kimetsu no Yaiba: Purātorēninguāku-hen
# 11975  55709                               Boku to Roboko Movie
# 11976  55714                                       Retro Future
# 11977  55717  Dekisokonai to Yobareta Motoeiyuu wa Jikka kar...
#
#                                       genre  \
# 0             Action, Award Winning, Sci-Fi
# 1                            Action, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# ...

# %%
anime['tags'] = anime['overview']+anime['genre']
anime = anime.drop(columns=['overview', 'genre'])
anime.head()
# Out:
# /var/folders/4l/vhl9mh4n00x7t930gk0lrc_m0000gn/T/ipykernel_9879/1874816049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime['tags'] = anime['overview']+anime['genre']
#    id                             name  \
# 0   1                     Cowboy Bebop
# 1   5  Cowboy Bebop: Tengoku no Tobira
# 2   6                           Trigun
# 3   7               Witch Hunter Robin
# 4   8                   Bouken Ou Beet
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=11978, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=11978, stop_words='english')

# %%
vector=cv.fit_transform(anime['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (11978, 11978)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.2261204 , 0.08392543, ..., 0.0761387 , 0.        ,
#         0.06660749],
#        [0.2261204 , 1.        , 0.11547005, ..., 0.0942809 , 0.02222222,
#         0.08247861],
#        [0.08392543, 0.11547005, 1.        , ..., 0.08164966, 0.        ,
#         0.08571429],
#        ...,
#        [0.0761387 , 0.0942809 , 0.08164966, ..., 1.        , 0.07856742,
#         0.        ],
#        [0.        , 0.02222222, 0.        , ..., 0.07856742, 1.        ,
#         0.05498574],
#        [0.06660749, 0.08247861, 0.08571429, ..., 0.        , 0.05498574,
#         1.        ]])

# %%
anime[anime['name']=="Trigun"].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(anime.iloc[i[0]]['name'])
# Out:
# Trigun
# Trigun: Badlands Rumble
# Trigun Stampede
# No Guns Life 2nd Season
# Sonyeon 007 Jihajeguk

# %%
def recommend(animes):
    index = anime[anime['name']==animes].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(anime.iloc[i[0]]['name'])

# %%
recommend("Dragon Ball Z")
# Out:
# Dragon Ball Z
# Dragon Ball Kai
# Dragon Ball GT
# Dragon Ball Z Movie 15: Fukkatsu no "F"
# Dragon Ball Z Movie 12: Fukkatsu no Fusion!! Gokuu to Vegeta

# %%
import pickle

# %%
pickle.dump(anime, open('anime_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('anime_list.pkl', 'rb'))
# Out:
#           id                                               name  \
# 0          1                                       Cowboy Bebop
# 1          5                    Cowboy Bebop: Tengoku no Tobira
# 2          6                                             Trigun
# 3          7                                 Witch Hunter Robin
# 4          8                                     Bouken Ou Beet
# ...      ...                                                ...
# 11973  55701                Kimetsu no Yaiba: Hashira Geiko-hen
# 11974  55702             Kimetsu no Yaiba: Purātorēninguāku-hen
# 11975  55709                               Boku to Roboko Movie
# 11976  55714                                       Retro Future
# 11977  55717  Dekisokonai to Yobareta Motoeiyuu wa Jikka kar...
#
#                                                  img_url  \
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# ...
